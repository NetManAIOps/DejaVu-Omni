# %%
from tqdm.notebook import tqdm
import multiprocessing
from typing import *
import pandas as pd
import os
import json
from pathlib import Path
from collections import defaultdict
import pickle
from concurrent.futures import ProcessPoolExecutor

DATASET = 'C'
TEST_RATE = .4
SAVE_ROOT = f'../data/{DATASET}'
os.makedirs(SAVE_ROOT, exist_ok=True)

# %% [markdown]
# ### Run Table

# %%
faults = pd.read_csv(f"/SSF/data/{DATASET}/faults.csv")
print(faults.node_type.unique())
faults['instance'] = faults['root_cause_node'].apply(lambda x: x.split()[0])
faults['anomaly_type'] = faults['node_type']
faults['st_time'] = faults['timestamp']
faults
# Out:
# ['Pod' 'Node CPU' 'Node Memory' 'Pod CPU' 'Pod Memory']
#       timestamp duration           root_cause_node  \
# 0    1645599600       5m        ts-basic-service-1
# 1    1645603200       5m     ts-preserve-service-1
# 2    1645606800       5m                 node3 CPU
# 3    1645614000       5m              node4 Memory
# 4    1645617600       5m              node3 Memory
# ..          ...      ...                       ...
# 164  1646470800       5m                 node4 CPU
# 165  1646474400       5m                 node3 CPU
# 166  1646492400       5m  ts-user-service-0 Memory
# 167  1646506800       5m              node3 Memory
# 168  1646510400       5m              node2 Memory
#
#                   experiment_type        failure_class    node_type  \
# 0             pod-network-corrupt  pod-network-corrupt          Pod
# 1             pod-network-corrupt  pod-network-corrupt          Pod
# 2       node-cpu-stress-lzy-k8s-3      node-cpu-stress     Node CPU
# 3    node-memory-stress-lzy-k8s-4   node-memory-stress  Node Memory
# 4    node-memory-stress-lzy-k8s-3   node-memory-stress  Node Memory
# ..                            ...                  ...          ...
# 164     node-cpu-stress-lzy-k8s-4      node-cpu-stress     Node CPU
# 165     node-cpu-stress-lzy-k8s-3      node-cpu-stress     Node CPU
# 166             pod-memory-stress    pod-memory-stress   Pod Memory
# 167  node-memory-stress-lzy-k8s-3   node-memory-stress  Node Memory
# 168  node-memory-stress-lzy-k8s-2   node-memory-stress  Node Memory
#
#                   instance anomaly_type     st_time
# 0       ts-basic-service-1          Pod  1645599600
# 1    ts-preserve-service-1          Pod  1645603200
# 2                    node3     Node CPU  1645606800
# 3                    node4  Node Memory  1645614000
# 4                    node3  Node Memory  1645617600
# ..                     ...          ...         ...
# 164                  node4     Node CPU  1646470800
# 165                  node3     Node CPU  1646474400
# 166      ts-user-service-0   Pod Memory  1646492400
# 167                  node3  Node Memory  1646506800
# 168                  node2  Node Memory  1646510400
#
# [169 rows x 9 columns]

# %%
run_table = faults[['instance', 'st_time', 'anomaly_type']]
run_table["anomaly_type"] = run_table["anomaly_type"].apply(lambda x: "[" + x + "]")
run_table['service'] = run_table['instance']
run_table["duration"] = [300] * len(run_table)
run_table["ed_time"] = run_table["st_time"] + run_table["duration"]
run_table["data_type"] = ["train"] * len(run_table)
run_table = run_table[['st_time','service','instance','anomaly_type','duration','ed_time','data_type']]
run_table.reset_index(drop=True, inplace=True)

anomaly_cnt = run_table.groupby(by="anomaly_type")["instance"].count()
anomaly_cnt_dict = anomaly_cnt.to_dict()
for anomaly, group in run_table.groupby(by="anomaly_type"):
    sample_cnt = int(anomaly_cnt_dict[anomaly] * TEST_RATE)
    group_index = group.index.to_list()
    test_choices = group_index[-sample_cnt:]
    for choice in test_choices:
        run_table.loc[choice, "data_type"] = "test"

anomaly_types = [item for item in run_table.anomaly_type.unique()]
anomaly_types.sort()
print(' '.join(anomaly_types))

run_table
# Out:
# [Node CPU] [Node Memory] [Pod CPU] [Pod Memory] [Pod]
# /tmp/ipykernel_833027/3061916839.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   run_table["anomaly_type"] = run_table["anomaly_type"].apply(lambda x: "[" + x + "]")
# /tmp/ipykernel_833027/3061916839.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   run_table['service'] = run_table['instance']
# /tmp/ipykernel_833027/3061916839.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   run_table["duration"] = [300] * len(run_table)
# /tmp/ipykernel_833027/3061916839.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   run_table["ed_time"] = run_table["st_time"] + run_table["duration"]
# /tmp/ipykernel_833027/3061916839.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   run_table["data_type"] = ["train"] * len(run_table)
#         st_time                service               instance   anomaly_type  \
# 0    1645599600     ts-basic-service-1     ts-basic-service-1          [Pod]
# 1    1645603200  ts-preserve-service-1  ts-preserve-service-1          [Pod]
# 2    1645606800                  node3                  node3     [Node CPU]
# 3    1645614000                  node4                  node4  [Node Memory]
# 4    1645617600                  node3                  node3  [Node Memory]
# ..          ...                    ...                    ...            ...
# 164  1646470800                  node4                  node4     [Node CPU]
# 165  1646474400                  node3                  node3     [Node CPU]
# 166  1646492400      ts-user-service-0      ts-user-service-0   [Pod Memory]
# 167  1646506800                  node3                  node3  [Node Memory]
# 168  1646510400                  node2                  node2  [Node Memory]
#
#      duration     ed_time data_type
# 0         300  1645599900     train
# 1         300  1645603500     train
# 2         300  1645607100     train
# 3         300  1645614300     train
# 4         300  1645617900     train
# ..        ...         ...       ...
# 164       300  1646471100      test
# 165       300  1646474700      test
# 166       300  1646492700      test
# 167       300  1646507100      test
# 168       300  1646510700      test
#
# [169 rows x 7 columns]

# %%
run_table.to_csv(os.path.join(SAVE_ROOT, 'run_table.csv'))

# %% [markdown]
# ### Anomalies

# %%
def load_pkl(filepath):
    with open(filepath, 'rb') as f:
        data = pickle.load(f)
    return data

metrics_df = load_pkl('/SSF/data/C/metrics.pkl')
metrics_df
# Out:
#                           serviceName   timestamp   value metric_kind  \
# 0         ts-admin-basic-info-service  1645596000     4.0       count
# 1         ts-admin-basic-info-service  1645596060     4.0       count
# 2         ts-admin-basic-info-service  1645596120     4.0       count
# 3         ts-admin-basic-info-service  1645596180     4.0       count
# 4         ts-admin-basic-info-service  1645596240     4.0       count
# ...                               ...         ...     ...         ...
# 62974086                          NaN  1646510760  7872.0         NaN
# 62974087                          NaN  1646510820  7872.0         NaN
# 62974088                          NaN  1646510880  7872.0         NaN
# 62974089                          NaN  1646510940  7872.0         NaN
# 62974090                          NaN  1646511000  7872.0         NaN
#
#                                                       name  pod  \
# 0                       ts-admin-basic-info-service##count  NaN
# 1                       ts-admin-basic-info-service##count  NaN
# 2                       ts-admin-basic-info-service##count  NaN
# 3                       ts-admin-basic-info-service##count  NaN
# 4                       ts-admin-basic-info-service##count  NaN
# ...                                                    ...  ...
# 62974086  ts-verification-code-service-1##jvm_class_loaded  NaN
# 62974087  ts-verification-code-service-1##jvm_class_loaded  NaN
# 62974088  ts-verification-code-service-1##jvm_class_loaded  NaN
# 62974089  ts-verification-code-service-1##jvm_class_loaded  NaN
# 62974090  ts-verification-code-service-1##jvm_class_loaded  NaN
#
#                metric_type
# 0                    count
# 1                    count
# 2                    count
# 3                    count
# 4                    count
# ...                    ...
# 62974086  jvm_class_loaded
# 62974087  jvm_class_loaded
# 62974088  jvm_class_loaded
# 62974089  jvm_class_loaded
# 62974090  jvm_class_loaded
#
# [62974091 rows x 7 columns]

# %%
metrics_df['cmdb'] = metrics_df['name'].map(lambda _: _.split('##')[0])
cmdb_excluded = ['jaeger-query', 'unknown']
metrics_df = metrics_df[~metrics_df['cmdb'].isin(cmdb_excluded)]
metrics_df = metrics_df.rename(columns={"metric_type": "kpi_name", "cmdb": "cmdb_id"})
metrics_df
# Out:
#                           serviceName   timestamp   value metric_kind  \
# 0         ts-admin-basic-info-service  1645596000     4.0       count
# 1         ts-admin-basic-info-service  1645596060     4.0       count
# 2         ts-admin-basic-info-service  1645596120     4.0       count
# 3         ts-admin-basic-info-service  1645596180     4.0       count
# 4         ts-admin-basic-info-service  1645596240     4.0       count
# ...                               ...         ...     ...         ...
# 62974086                          NaN  1646510760  7872.0         NaN
# 62974087                          NaN  1646510820  7872.0         NaN
# 62974088                          NaN  1646510880  7872.0         NaN
# 62974089                          NaN  1646510940  7872.0         NaN
# 62974090                          NaN  1646511000  7872.0         NaN
#
#                                                       name  pod  \
# 0                       ts-admin-basic-info-service##count  NaN
# 1                       ts-admin-basic-info-service##count  NaN
# 2                       ts-admin-basic-info-service##count  NaN
# 3                       ts-admin-basic-info-service##count  NaN
# 4                       ts-admin-basic-info-service##count  NaN
# ...                                                    ...  ...
# 62974086  ts-verification-code-service-1##jvm_class_loaded  NaN
# 62974087  ts-verification-code-service-1##jvm_class_loaded  NaN
# 62974088  ts-verification-code-service-1##jvm_class_loaded  NaN
# 62974089  ts-verification-code-service-1##jvm_class_loaded  NaN
# 62974090  ts-verification-code-service-1##jvm_class_loaded  NaN
#
#                   kpi_name                         cmdb_id
# 0                    count     ts-admin-basic-info-service
# 1                    count     ts-admin-basic-info-service
# 2                    count     ts-admin-basic-info-service
# 3                    count     ts-admin-basic-info-service
# 4                    count     ts-admin-basic-info-service
# ...                    ...                             ...
# 62974086  jvm_class_loaded  ts-verification-code-service-1
# 62974087  jvm_class_loaded  ts-verification-code-service-1
# 62974088  jvm_class_loaded  ts-verification-code-service-1
# 62974089  jvm_class_loaded  ts-verification-code-service-1
# 62974090  jvm_class_loaded  ts-verification-code-service-1
#
# [62974013 rows x 8 columns]

# %%
nodes = list(metrics_df.cmdb_id.unique())
nodes.sort()
print(f"{len(nodes)} nodes: \n{' '.join(nodes)}")
node_hash = {node: index for index, node in enumerate(nodes)}

import sys
sys.path.insert(0, '/SSF/DejaVu-Omni')
from failure_dependency_graph.parse_yaml_graph_config import parse_yaml_graph_config

graph = parse_yaml_graph_config('/SSF/data/C/graphs/graph_1645779600.yml', Path('tmp'))
src, tgt = [], []
for i, j in graph.edges:
    if i in nodes and j in nodes:
        src.append(j)
        tgt.append(i)
src = [node_hash[item] for item in src]
# tgt = [node_hash[item] for item in tgt]
print('src: ', src)
print('tgt: ', tgt)
# Out:
# 171 nodes:
# node1 node2 node3 node4 ts-admin-basic-info-service ts-admin-basic-info-service-0 ts-admin-order-service ts-admin-order-service-0 ts-admin-route-service ts-admin-route-service-0 ts-admin-travel-service ts-admin-travel-service-0 ts-admin-user-service ts-admin-user-service-0 ts-assurance-mongo ts-assurance-mongo-0 ts-assurance-service ts-assurance-service-0 ts-auth-mongo ts-auth-mongo-0 ts-auth-service ts-auth-service-0 ts-auth-service-1 ts-avatar-service-0 ts-avatar-service-1 ts-basic-service ts-basic-service-0 ts-basic-service-1 ts-basic-service-2 ts-cancel-service ts-cancel-service-0 ts-cancel-service-1 ts-config-mongo ts-config-mongo-0 ts-config-service ts-config-service-0 ts-config-service-1 ts-consign-mongo ts-consign-mongo-0 ts-consign-price-mongo ts-consign-price-mongo-0 ts-consign-price-service ts-consign-price-service-0 ts-consign-price-service-1 ts-consign-service ts-consign-service-0 ts-consign-service-1 ts-contacts-mongo ts-contacts-mongo-0 ts-contacts-service ts-contacts-service-0 ts-contacts-service-1 ts-execute-service ts-execute-service-0 ts-execute-service-1 ts-food-map-mongo ts-food-map-mongo-0 ts-food-map-service ts-food-map-service-0 ts-food-map-service-1 ts-food-mongo ts-food-mongo-0 ts-food-service ts-food-service-0 ts-food-service-1 ts-inside-payment-mongo ts-inside-payment-mongo-0 ts-inside-payment-service ts-inside-payment-service-0 ts-inside-payment-service-1 ts-news-service-0 ts-news-service-1 ts-notification-service ts-notification-service-0 ts-notification-service-1 ts-order-mongo ts-order-mongo-0 ts-order-other-mongo ts-order-other-mongo-0 ts-order-other-service ts-order-other-service-0 ts-order-other-service-1 ts-order-other-service-2 ts-order-service ts-order-service-0 ts-order-service-1 ts-order-service-2 ts-payment-mongo ts-payment-mongo-0 ts-payment-service ts-payment-service-0 ts-payment-service-1 ts-payment-service-2 ts-preserve-other-service ts-preserve-other-service-0 ts-preserve-other-service-1 ts-preserve-service ts-preserve-service-0 ts-preserve-service-1 ts-price-mongo ts-price-mongo-0 ts-price-service ts-price-service-0 ts-price-service-1 ts-rebook-service ts-rebook-service-0 ts-rebook-service-1 ts-route-mongo ts-route-mongo-0 ts-route-plan-service ts-route-plan-service-0 ts-route-plan-service-1 ts-route-service ts-route-service-0 ts-route-service-1 ts-seat-service ts-seat-service-0 ts-seat-service-1 ts-security-mongo ts-security-mongo-0 ts-security-service ts-security-service-0 ts-security-service-1 ts-station-mongo ts-station-mongo-0 ts-station-service ts-station-service-0 ts-station-service-1 ts-station-service-2 ts-ticket-office-mongo ts-ticket-office-mongo-0 ts-ticket-office-service-0 ts-ticket-office-service-1 ts-ticketinfo-service ts-ticketinfo-service-0 ts-ticketinfo-service-1 ts-train-mongo ts-train-mongo-0 ts-train-service ts-train-service-0 ts-train-service-1 ts-train-service-2 ts-travel-mongo ts-travel-mongo-0 ts-travel-plan-service ts-travel-plan-service-0 ts-travel-plan-service-1 ts-travel-service ts-travel-service-0 ts-travel-service-1 ts-travel-service-2 ts-travel2-mongo ts-travel2-mongo-0 ts-travel2-service ts-travel2-service-0 ts-travel2-service-1 ts-ui-dashboard ts-ui-dashboard-0 ts-user-mongo ts-user-mongo-0 ts-user-service ts-user-service-0 ts-user-service-1 ts-user-service-2 ts-verification-code-service ts-verification-code-service-0 ts-verification-code-service-1 ts-voucher-mysql-0 ts-voucher-service-0 ts-voucher-service-1 ts-voucher-service-2
# src:  [41, 37, 79, 83, 55, 158, 112, 79, 115, 133, 138, 151, 107, 79, 83, 118, 115, 133, 138, 112, 83, 142, 79, 67, 83, 160, 49, 16, 147, 115, 133, 160, 62, 120, 125, 83, 39, 125, 75, 99, 14, 147, 125, 57, 60, 164, 18, 79, 83, 153, 147, 34, 89, 79, 83, 65, 125, 138, 112, 101, 47, 123, 32, 87, 25, 136, 125, 77, 79, 49, 16, 153, 115, 133, 62, 160, 120, 125, 44, 52, 57, 160, 153, 112, 120, 164, 147, 29, 109, 96, 144, 41, 83, 101, 16, 62, 20, 115, 67, 25, 4, 49, 12, 125, 34, 8, 6, 104, 72, 89, 133, 10, 138, 79, 93, 156, 157, 3, 2, 3, 0, 2, 0, 1, 1, 1, 2, 0, 1, 3, 0, 2, 1, 0, 1, 1, 3, 1, 1, 1, 2, 3, 1, 1, 2, 0, 0, 3, 2, 1, 2, 0, 0, 3, 1, 1, 0, 0, 1, 0, 3, 0, 1, 1, 2, 3, 1, 3, 2, 0, 1, 0, 2, 1, 0, 0, 1, 0, 1, 3, 1, 2, 1, 0, 3, 1, 0, 0, 3, 2, 1, 0, 0, 1, 2, 0, 3, 0, 3, 0, 1, 1, 2, 1, 3, 1, 0, 2, 1, 0, 2, 3, 0, 1, 0, 1, 2, 1, 3, 0, 1, 2, 0, 3, 1]
# tgt:  [44, 44, 52, 52, 57, 160, 153, 153, 153, 153, 153, 153, 112, 120, 120, 120, 147, 147, 147, 147, 147, 147, 29, 29, 29, 29, 96, 96, 96, 96, 96, 96, 96, 96, 96, 96, 41, 83, 83, 101, 16, 62, 62, 62, 62, 20, 20, 115, 115, 115, 115, 115, 67, 67, 67, 67, 25, 25, 25, 25, 49, 125, 34, 89, 133, 138, 79, 79, 93, 93, 93, 93, 93, 93, 93, 93, 93, 93, 156, 156, 156, 156, 156, 156, 156, 156, 156, 156, 156, 156, 156, 156, 156, 156, 156, 156, 156, 156, 156, 156, 156, 156, 156, 156, 156, 156, 156, 156, 156, 156, 156, 156, 156, 156, 156, 156, 156, 5, 7, 9, 11, 13, 15, 17, 19, 21, 22, 23, 24, 26, 27, 28, 30, 31, 33, 35, 36, 38, 40, 42, 43, 45, 46, 48, 50, 51, 53, 54, 56, 58, 59, 61, 63, 64, 66, 68, 69, 70, 71, 73, 74, 76, 78, 80, 81, 82, 84, 85, 86, 88, 90, 91, 92, 94, 95, 97, 98, 100, 102, 103, 105, 106, 108, 110, 111, 113, 114, 116, 117, 119, 121, 122, 124, 126, 127, 128, 130, 131, 132, 134, 135, 137, 139, 140, 141, 143, 145, 146, 148, 149, 150, 152, 154, 155, 157, 159, 161, 162, 163, 165, 166, 167, 168, 169, 170]

# %%
import sys
sys.path.insert(0, '/SSF/DejaVu-Omni/DiagFusion/')
from detector.k_sigma import Ksigma

def process_task(df, case_id, st_time, ed_time):
    detector = Ksigma()
    rt = []
    scheduler = tqdm(total=len(df), desc=f"case:{case_id}, detecting")
    for instance, ins_group in df.groupby(by="cmdb_id"):
        for kpi, kpi_group in ins_group.groupby(by="kpi_name"):
            res = detector.detection(kpi_group, "value", st_time, ed_time)
            if res[0] is True:
                rt.append([int(res[1]), instance, kpi, res[2]])
        scheduler.update(len(ins_group))
    return rt

# %%
metric_dict = {}
tasks = []
pool = multiprocessing.Pool(processes=10)
for case_id, case in run_table.iterrows():
    # 故障前60个点，故障后0个点
    sample_interval = 60
    st_time = case["st_time"] - (sample_interval * 60)
    ed_time = case["ed_time"] + (sample_interval * 0)
    task = pool.apply_async(
        process_task,
        (
            metrics_df.query(f"timestamp >= {st_time} & timestamp < {ed_time}"),
            case_id,
            st_time,
            ed_time,
        ),
    )
    tasks.append((case_id, task))
pool.close()
pool.join()
for case_id, task in tasks:
    metric_dict[case_id] = task.get()

# %%
anomaly_path = os.path.join(SAVE_ROOT, 'anomalies')
os.makedirs(anomaly_path, exist_ok=True)
with open(os.path.join(anomaly_path, 'demo_metric.json'), "w") as w:
    json.dump(metric_dict, w)
